# %%
# This is old
import requests
import json
import matplotlib.pyplot as plt
% matplotlib inline
from datetime import datetime
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np

# These are new
import tweepy

# Load secret keys
#with open('api_keys.json-example') as f:
#    api_keys = json.loads(f.read())

# %%
with open('api_keys.json-tweeter') as f:
    api_keys = json.loads(f.read())

# Load API keys
consumer_key = api_keys['consumer_key']
consumer_secret = api_keys['consumer_secret']
access_token = api_keys['access_token']
access_token_secret = api_keys['access_token_secret']

# Authenticate Tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
with open('api_keys.json-tweeter') as f:
    api_keys = json.loads(f.read())

# Load API keys
consumer_key = api_keys['consumer_key']
consumer_secret = api_keys['consumer_secret']
access_token = api_keys['access_token']
access_token_secret = api_keys['access_token_secret']

# Authenticate Tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)

# %%
def stream_saver(search_terms):
    readyToWrite = []
    for s in tweepy.Cursor(api.search, q=search_terms).items(20):
        if s.in_reply_to_status_id == None and s.entities['user_mentions'] == []:
        #if s.in_reply_to_status_id == None:
            #print(s.text)
            #print(s.id)
            #print(s.created_at)
            #print(s.user.id)
            #print(s.user.screen_name)
            readyToWrite.append({
                'tweetContent':s.text,
                'tweetUser':s.user.screen_name,
                'tweetTime':s.created_at,
                'tweetID':s.id
            })
    readyToWrite_df = pd.DataFrame(readyToWrite)
    readyToWrite_df.to_csv("test.csv")
    return readyToWrite_df
stream_saver('hot')
# Out:
#                                          tweetContent             tweetID  \
# 0   RT @vantaekim: taehyung looks so hot when he’s...  925475688534237185
# 1   RT @Genius: “man’s not dumb. man’s not hot. ma...  925475687565266945
# 2   RT @asian_only77: 💓💜#hotasian #milf💜💓with gorg...  925475687183532032
# 3                                     @ladyasabea Bbf  925475686931992577
# 4   RT @PopCrave: “Havana” has a 50/50 chance of e...  925475686831280128
# 5   RT @shrimp309: 상상만으로 짜릿하지 않나요 지금으로부터 1달만 지나면.....  925475685711228928
# 6      Stephanie Branton https://t.co/yaYThdh9dk #hot  925475685237493761
# 7   RT @Lovingrahulxxx: Morning erection she is da...  925475684767674369
# 8   halloween is inherently sexy. demons? the devi...  925475684318957568
# 9   RT @bad_shade: Hot Spring Fun! #NSFW\nhttps://...  925475683773665282
# 10  I liked a @YouTube video https://t.co/1nh0hhf1...  925475681915502594
# 11  RT @umdoisvaivendo: #tercadamaldade #TercaDasT...  925475681403883520
# 12      RT @SiendoHorny: Hot! https://t.co/zZgycw4zrX  925475681143853056
# 13  RT @Karate_Horse: Wow fall HGTV lineup coming ...  925475680476901376
# 14       RT @daisymarquez_: Wow my friends are so hot  925475677171798021
# 15  RT @luviMUFC: CHELSEA FANS :\n\n"Two plus two ...  925475676844474368
# 16  #Gourmet #hot #chili Sauces When you need the ...  925475671538831360
# 17               @RavenRaine69 Wow! So hot to trot! 😍  925475670230294528
# 18  RT @gibfahn: v8.9.0 of @nodejs is out: https:/...  925475669047308288
# 19  RT @Corstador: Who tf said Wendy Williams over...  925475668988641280
#
#              tweetTime        tweetUser
# 0  2017-10-31 21:32:53         momoijee
# 1  2017-10-31 21:32:53       Naa_Meryer
# 2  2017-10-31 21:32:52        StWicked1
# 3  2017-10-31 21:32:52      hOt_SuBjEcT
# 4  2017-10-31 21:32:52   KarolTorresOfc
# 5  2017-10-31 21:32:52    Juhangnyeon39
# 6  2017-10-31 21:32:52  playmatestweets
# 7  2017-10-31 21:32:52      FatimA3355A
# 8  2017-10-31 21:32:52      OINKimmaPIG
# 9  2017-10-31 21:32:52        Bad_Hyena
# 10 2017-10-31 21:32:51          jonKD35
# 11 2017-10-31 21:32:51        oxnar_sex
# 12 2017-10-31 21:32:51   CamiloDiaz1789
# 13 2017-10-31 21:32:51    CharlesMynard
# 14 2017-10-31 21:32:50    LondonGatling
# 15 2017-10-31 21:32:50         Ki_mutai
# 16 2017-10-31 21:32:49  aujosemontezuma
# 17 2017-10-31 21:32:48    PaulLangton10
# 18 2017-10-31 21:32:48         GeorgeCr
# 19 2017-10-31 21:32:48         Yann_129

# %% [markdown]
# # I try to save the records into the database.

# %%
import sqlalchemy
from sqlalchemy import (Table, Column, Integer, String, Float, Date,
                        MetaData, create_engine)
from sqlalchemy.sql import select
from datetime import date

# %%
engine = create_engine('sqlite:///test.db')
metadata = MetaData()

tweet = sqlalchemy.Table('tweet', metadata,
                            Column('id', String(20), primary_key=True),
                            Column('content', String(500)),
                            Column('author', String(10)),
                            Column('time',String(15)))

query = tweet.create(engine, checkfirst=True)

# %%
with open('api_keys.json-tweeter') as f:
    api_keys = json.loads(f.read())

# Load API keys
consumer_key = api_keys['consumer_key']
consumer_secret = api_keys['consumer_secret']
access_token = api_keys['access_token']
access_token_secret = api_keys['access_token_secret']

# Authenticate Tweepy
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth)


connection = engine.connect()
class MyStreamListener(tweepy.StreamListener):
    def on_status(self, status):
        insert_query = tweet.insert().values(id = status.id,
                                        content = status.text,
                                        author = status.user.screen_name,
                                        time = status.created_at)
        insert_query.compile()
        #connection = engine.connect()
        connection.execute(insert_query)

myStreamListener = MyStreamListener()
myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)

myStream.filter(track=[u'pizza'], async=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-5ef477ba329a> in <module>()
#      28 myStream = tweepy.Stream(auth = api.auth, listener=myStreamListener)
#      29
# ---> 30 myStream.filter(track=[u'pizza'], async=False)
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     322             next_status_obj = buf.read_len(length)
#     323             if self.running:
# --> 324                 self._data(next_status_obj)
#     325
#     326             # # Note: keep-alive newlines might be inserted before each length value.
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in _data(self, data)
#     295
#     296     def _data(self, data):
# --> 297         if self.listener.on_data(data) is False:
#     298             self.running = False
#     299
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/tweepy/streaming.py in on_data(self, raw_data)
#      52         if 'in_reply_to_status_id' in data:
#      53             status = Status.parse(self.api, data)
# ---> 54             if self.on_status(status) is False:
#      55                 return False
#      56         elif 'delete' in data:
#
# <ipython-input-4-5ef477ba329a> in on_status(self, status)
#      23         insert_query.compile()
#      24         #connection = engine.connect()
# ---> 25         connection.execute(insert_query)
#      26
#      27 myStreamListener = MyStreamListener()
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     943             raise exc.ObjectNotExecutableError(object)
#     944         else:
# --> 945             return meth(self, multiparams, params)
#     946
#     947     def _execute_function(self, func, multiparams, params):
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     261     def _execute_on_connection(self, connection, multiparams, params):
#     262         if self.supports_execution:
# --> 263             return connection._execute_clauseelement(self, multiparams, params)
#     264         else:
#     265             raise exc.ObjectNotExecutableError(self)
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1051             compiled_sql,
#    1052             distilled_params,
# -> 1053             compiled_sql, distilled_params
#    1054         )
#    1055         if self._has_events or self.engine._has_events:
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1207
#    1208         if context.should_autocommit and self._root.__transaction is None:
# -> 1209             self._root._commit_impl(autocommit=True)
#    1210
#    1211         # for "connectionless" execution, we have to close this
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _commit_impl(self, autocommit)
#     721             self.engine.dialect.do_commit(self.connection)
#     722         except BaseException as e:
# --> 723             self._handle_dbapi_exception(e, None, None, None, None)
#     724         finally:
#     725             if not self.__invalid and \
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1403                 )
#    1404             else:
# -> 1405                 util.reraise(*exc_info)
#    1406
#    1407         finally:
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     185         if value.__traceback__ is not tb:
#     186             raise value.with_traceback(tb)
# --> 187         raise value
#     188
#     189 else:
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/base.py in _commit_impl(self, autocommit)
#     719             self.engine.logger.info("COMMIT")
#     720         try:
# --> 721             self.engine.dialect.do_commit(self.connection)
#     722         except BaseException as e:
#     723             self._handle_dbapi_exception(e, None, None, None, None)
#
# /home/yabo/anaconda3/lib/python3.6/site-packages/sqlalchemy/engine/default.py in do_commit(self, dbapi_connection)
#     441
#     442     def do_commit(self, dbapi_connection):
# --> 443         dbapi_connection.commit()
#     444
#     445     def do_close(self, dbapi_connection):
#
# KeyboardInterrupt:

# %%
s = select([tweet]) # Equivilant to "SELECT * FROM students"
result = connection.execute(s)
for i in result:
    print(i)
# Out:
# ('925520920671850496', 'cheguei em casa tinha coca gelada pizza e beci e amanhã meu amorzinho chega.... simplesmente uma mulher plena..', 'gasbrella', '2017-11-01 00:32:37')
# ('925520920973926400', 'Crl Dayane comeu pizza e agora tá comendo lasanha 😲😲😲😲', 'ThaissaFaro', '2017-11-01 00:32:37')
# ('925520924497055744', 'RT @Dicarop_: Necesito un hombre en mi vida que todo lo quiera arreglar con pizza y sexo!!', 'Divagando_ando', '2017-11-01 00:32:38')
# ('925520924174094336', '@Rebe_lag58 pizza', 'duftdead', '2017-11-01 00:32:38')
# ('925520925893844993', 'RT @EnciclopediaCL: Se imaginan estar carreteando y un weon llegue disfrazado de Pizza con Piña o de Pimentones a la parrilla??? Le saco la…', 'rodolfoxoliz', '2017-11-01 00:32:38')
# ('925520928385232897', 'hoje somente uma pizza de calabresa com queijo seria capaz de salvar minha vida', '1993atmosphere', '2017-11-01 00:32:39')
# ('925520933057695744', '@jjones_74 It’s pretty basic frozen, boxed pizza taste, I think I’d take Totino’s over it.', 'Birm', '2017-11-01 00:32:40')
# ('925520934123048962', 'RT @aidamrtnez98: @NoeMoliGa me vale con dinero, pero con pizza lo prefiero más JAJAJAJAJA https://t.co/Kk7nmtmetW', 'NoeMoliGa', '2017-11-01 00:32:40')
